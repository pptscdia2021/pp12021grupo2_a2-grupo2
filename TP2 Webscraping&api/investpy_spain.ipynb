# %%
import investpy
import pandas as pd

# %%
#Obtener la tabla en tiempo real de la bolsa de españa
investpy.stocks.get_stocks_overview(country='spain', as_json = False , n_results = 35)
# Out:
#    country                         name symbol     last      high       low  \
# 0    spain                          ACS    ACS   23.400   23.4900   23.1050
# 1    spain                   Atresmedia    A3M    3.572    3.5900    3.4520
# 2    spain                     Acerinox    ACX   11.160   11.2050   10.9420
# 3    spain                         BBVA   BBVA    5.410    5.4600    5.2900
# 4    spain                    Bankinter    BKT    4.948    4.9700    4.8890
# 5    spain                      Acciona    ANA  144.600  146.8000  143.4000
# 6    spain                    Caixabank   CABK    2.576    2.5920    2.5250
# 7    spain                       Enagas   ENAG   19.240   19.3300   19.0750
# 8    spain                          FCC    FCC   10.820   10.9500   10.7800
# 9    spain               Naturgy Energy   NTGY   21.550   21.5950   21.4050
# 10   spain                       Gamesa  SGREN   22.500   22.7000   22.2500
# ...
