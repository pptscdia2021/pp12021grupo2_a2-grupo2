# %%
import investpy
import pandas as pd

# %%
#Obtener la tabla en tiempo real de la bolsa de españa
df = investpy.stocks.get_stocks_overview(country='spain', as_json = False , n_results = 35)

# %%
print(df)
# Out:
#    country                         name symbol      last      high       low  \
# 0    spain                          ACS    ACS   24.0700   24.2600   23.6350
# 1    spain                   Atresmedia    A3M    3.8500    3.8560    3.6920
# 2    spain                     Acerinox    ACX   11.0800   11.1800   10.8700
# 3    spain                         BBVA   BBVA    5.7800    5.7900    5.6180
# 4    spain                    Bankinter    BKT    5.2480    5.2560    5.0800
# 5    spain                      Acciona    ANA  148.9000  148.9000  144.8000
# 6    spain                    Caixabank   CABK    2.7500    2.7500    2.6600
# 7    spain                       Enagas   ENAG   19.2050   19.2450   19.0250
# 8    spain                          FCC    FCC   10.8200   10.8400   10.5200
# 9    spain               Naturgy Energy   NTGY   21.7000   21.7250   21.5400
# 10   spain                       Gamesa  SGREN   23.0100   23.3300   22.8950
# 11   spain                      Grifols   GRLS   22.3300   22.4800   21.8950
# 12   spain                    Ferrovial    FER   26.4900   26.6950   25.8500
# 13   spain                Red Electrica    REE   17.4050   17.4770   17.2720
# 14   spain                      Inditex    ITX   32.1850   32.3600   31.8850
# 15   spain                       Repsol    REP   10.9830   11.0620   10.7720
# 16   spain                    Iberdrola    IBE    9.1960    9.2720    9.1820
# 17   spain                      Indra A    IDR    9.5200    9.5700    9.4500
# 18   spain                       Mapfre    MAP    1.8890    1.8950    1.8570
# 19   spain                   Telefonica    TEF    4.1750    4.1780    4.0840
# 20   spain                     Mediaset    TL5    5.0150    5.0600    4.9300
# 21   spain                        Sacyr   SCYR    2.2000    2.2360    2.1340
# 22   spain            Banco de Sabadell    ACS    0.7150    0.7150    0.6684
# 23   spain                    Santander    SAN    3.2025    3.2025    3.1005
# 24   spain        Inmobiliaria Colonial    COL    8.8300    8.9100    8.7550
# 25   spain            Tecnicas Reunidas    TRE    8.4800    8.4800    8.2150
# 26   spain                          OHL    OHL    0.6270    0.6280    0.6110
# 27   spain                          IAG   ICAG    2.1760    2.1800    2.0590
# 28   spain                   Ebro Foods   EBRO   16.6690   17.1490   16.6100
# 29   spain                       Endesa    ELE   18.2000   18.3750   18.1020
# 30   spain                      Amadeus    AMA   58.9300   59.5900   57.1700
# 31   spain                          DIA   DIDA    0.0162    0.0227    0.0144
# 32   spain           Vertice 360 Grados   VTSG    3.6550    3.8400    3.6000
# 33   spain                 Laborat.Rovi   ROVI   55.1000   56.8000   54.5000
# 34   spain  General Alquiler Maquinaria   GALQ    1.5600    1.5600    1.5600
#
#      change change_percentage   turnover currency
# 0    +0.560            +2.38%     908770      EUR
# 1    +0.116            +3.11%     234200      EUR
# 2    -0.020            -0.18%     917400      EUR
# 3    +0.119            +2.10%   19530000      EUR
# 4    +0.152            +2.98%    3040000      EUR
# 5    +1.600            +1.09%     100370      EUR
# 6    +0.101            +3.81%   11780000      EUR
# 7    +0.115            +0.60%     697150      EUR
# 8    +0.260            +2.46%      27170      EUR
# 9    +0.120            +0.56%          0      EUR
# 10   +0.220            +0.97%     599990      EUR
# 11   +0.430            +1.96%     681290      EUR
# 12   +0.810            +3.15%    1100000      EUR
# 13   +0.075            +0.43%     684850      EUR
# 14   +0.475            +1.50%    1630000      EUR
# 15   +0.269            +2.51%    8240000      EUR
# 16   -0.022            -0.24%    8550000      EUR
# 17   +0.070            +0.74%     399460      EUR
# 18   +0.029            +1.56%    3320000      EUR
# 19  +0.0765            +1.87%    9920000      EUR
# 20   +0.027            +0.54%     300760      EUR
# 21   +0.038            +1.76%    4150000      EUR
# 22  +0.0496            +7.45%   53200000      EUR
# 23  +0.1035            +3.34%   38870000      EUR
# 24   +0.120            +1.38%     520740      EUR
# 25   +0.325            +3.99%     352940      EUR
# 26   +0.016            +2.62%    2490000      EUR
# 27   +0.128            +6.25%   30320000      EUR
# 28   +0.039            +0.23%      97760      EUR
# 29   +0.060            +0.33%     923820      EUR
# 30   +2.000            +3.51%    1310000      EUR
# 31  +0.0019           +13.29%  231090000      EUR
# 32  -0.0500            -1.35%      27660      EUR
# 33   -1.500            -2.65%      69350      EUR
# 34   +0.000            +0.00%       2560      EUR

# %%
df = df.join(df['change_percentage'].str.partition('%')[[0, 1]]).rename({0: 'G/P', 1: '%'}, axis=1)
df.sort_values(by='G/P', ascending = False)
df.head()
# Out:
#   country        name symbol    last    high     low  change  \
# 0   spain         ACS    ACS  24.070  24.260  23.635  +0.560
# 1   spain  Atresmedia    A3M   3.850   3.856   3.692  +0.116
# 2   spain    Acerinox    ACX  11.080  11.180  10.870  -0.020
# 3   spain        BBVA   BBVA   5.780   5.790   5.618  +0.119
# 4   spain   Bankinter    BKT   5.248   5.256   5.080  +0.152
#
#   change_percentage  turnover currency    G/P  %
# 0            +2.38%    908770      EUR  +2.38  %
# 1            +3.11%    234200      EUR  +3.11  %
# 2            -0.18%    917400      EUR  -0.18  %
# 3            +2.10%  19530000      EUR  +2.10  %
# 4            +2.98%   3040000      EUR  +2.98  %

# %%
df.sort_values(by='high', ascending = False)
# Out:
#    country                         name symbol      last      high       low  \
# 5    spain                      Acciona    ANA  148.9000  148.9000  144.8000
# 30   spain                      Amadeus    AMA   58.9300   59.5900   57.1700
# 33   spain                 Laborat.Rovi   ROVI   55.1000   56.8000   54.5000
# 14   spain                      Inditex    ITX   32.1850   32.3600   31.8850
# 12   spain                    Ferrovial    FER   26.4900   26.6950   25.8500
# 0    spain                          ACS    ACS   24.0700   24.2600   23.6350
# 10   spain                       Gamesa  SGREN   23.0100   23.3300   22.8950
# 11   spain                      Grifols   GRLS   22.3300   22.4800   21.8950
# 9    spain               Naturgy Energy   NTGY   21.7000   21.7250   21.5400
# 7    spain                       Enagas   ENAG   19.2050   19.2450   19.0250
# 29   spain                       Endesa    ELE   18.2000   18.3750   18.1020
# 13   spain                Red Electrica    REE   17.4050   17.4770   17.2720
# 28   spain                   Ebro Foods   EBRO   16.6690   17.1490   16.6100
# 2    spain                     Acerinox    ACX   11.0800   11.1800   10.8700
# 15   spain                       Repsol    REP   10.9830   11.0620   10.7720
# 8    spain                          FCC    FCC   10.8200   10.8400   10.5200
# 17   spain                      Indra A    IDR    9.5200    9.5700    9.4500
# 16   spain                    Iberdrola    IBE    9.1960    9.2720    9.1820
# 24   spain        Inmobiliaria Colonial    COL    8.8300    8.9100    8.7550
# 25   spain            Tecnicas Reunidas    TRE    8.4800    8.4800    8.2150
# 3    spain                         BBVA   BBVA    5.7800    5.7900    5.6180
# 4    spain                    Bankinter    BKT    5.2480    5.2560    5.0800
# 20   spain                     Mediaset    TL5    5.0150    5.0600    4.9300
# 19   spain                   Telefonica    TEF    4.1750    4.1780    4.0840
# 1    spain                   Atresmedia    A3M    3.8500    3.8560    3.6920
# 32   spain           Vertice 360 Grados   VTSG    3.6550    3.8400    3.6000
# 23   spain                    Santander    SAN    3.2025    3.2025    3.1005
# 6    spain                    Caixabank   CABK    2.7500    2.7500    2.6600
# 21   spain                        Sacyr   SCYR    2.2000    2.2360    2.1340
# 27   spain                          IAG   ICAG    2.1760    2.1800    2.0590
# 18   spain                       Mapfre    MAP    1.8890    1.8950    1.8570
# 34   spain  General Alquiler Maquinaria   GALQ    1.5600    1.5600    1.5600
# 22   spain            Banco de Sabadell    ACS    0.7150    0.7150    0.6684
# 26   spain                          OHL    OHL    0.6270    0.6280    0.6110
# 31   spain                          DIA   DIDA    0.0162    0.0227    0.0144
#
#      change change_percentage   turnover currency     G/P  %
# 5    +1.600            +1.09%     100370      EUR   +1.09  %
# 30   +2.000            +3.51%    1310000      EUR   +3.51  %
# 33   -1.500            -2.65%      69350      EUR   -2.65  %
# 14   +0.475            +1.50%    1630000      EUR   +1.50  %
# 12   +0.810            +3.15%    1100000      EUR   +3.15  %
# 0    +0.560            +2.38%     908770      EUR   +2.38  %
# 10   +0.220            +0.97%     599990      EUR   +0.97  %
# 11   +0.430            +1.96%     681290      EUR   +1.96  %
# 9    +0.120            +0.56%          0      EUR   +0.56  %
# 7    +0.115            +0.60%     697150      EUR   +0.60  %
# 29   +0.060            +0.33%     923820      EUR   +0.33  %
# 13   +0.075            +0.43%     684850      EUR   +0.43  %
# 28   +0.039            +0.23%      97760      EUR   +0.23  %
# 2    -0.020            -0.18%     917400      EUR   -0.18  %
# 15   +0.269            +2.51%    8240000      EUR   +2.51  %
# 8    +0.260            +2.46%      27170      EUR   +2.46  %
# 17   +0.070            +0.74%     399460      EUR   +0.74  %
# 16   -0.022            -0.24%    8550000      EUR   -0.24  %
# 24   +0.120            +1.38%     520740      EUR   +1.38  %
# 25   +0.325            +3.99%     352940      EUR   +3.99  %
# 3    +0.119            +2.10%   19530000      EUR   +2.10  %
# 4    +0.152            +2.98%    3040000      EUR   +2.98  %
# 20   +0.027            +0.54%     300760      EUR   +0.54  %
# 19  +0.0765            +1.87%    9920000      EUR   +1.87  %
# 1    +0.116            +3.11%     234200      EUR   +3.11  %
# 32  -0.0500            -1.35%      27660      EUR   -1.35  %
# 23  +0.1035            +3.34%   38870000      EUR   +3.34  %
# 6    +0.101            +3.81%   11780000      EUR   +3.81  %
# 21   +0.038            +1.76%    4150000      EUR   +1.76  %
# 27   +0.128            +6.25%   30320000      EUR   +6.25  %
# 18   +0.029            +1.56%    3320000      EUR   +1.56  %
# 34   +0.000            +0.00%       2560      EUR   +0.00  %
# 22  +0.0496            +7.45%   53200000      EUR   +7.45  %
# 26   +0.016            +2.62%    2490000      EUR   +2.62  %
# 31  +0.0019           +13.29%  231090000      EUR  +13.29  %

# %%
df["G/P"] = df["G/P"].apply(pd.to_numeric)

# %%
print(type(df['G/P']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df["G/P"] = pd.to_numeric(df["G/P"])
print(type(df['G/P']))
# Out:
# <class 'pandas.core.series.Series'>
